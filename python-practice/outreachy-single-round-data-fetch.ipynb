# %%
# requests is for downloading data(text) from the web.
import requests

# pattern and beautifulsoup are for navigating through DOM
from pattern import web

import csv

import re

def get_html(url):
    """ Fetch the html code from given url
        Returns pattern.web.Element
    """
    html = web.URL(url, method='GET')
    #print(type(html.download())) # str
    html_doc = html.download()
    
    #Keeping html related to only accepted participants 
    mid = html_doc.split('h1 id="Accepted_Participants"')
    required_html = mid[-1].split('h1 id="Participating_Organizations"')[0]
    match = re.search('Congratulations to \d+', required_html)
    print(match.group())
    required_html = required_html[required_html.index(match.group()) : ]
    
    dom = web.Element(required_html)
    print(dom)
    #print("done :)")
    return dom

def get_orgs(dom):
    """Get name of all participated orgs
       Returns list
    """
    
    orgs = []
    for org in dom.by_tag('h2'):
        this_org = org.content.encode('ascii','ignore')
        if not this_org.startswith('Org'):
            orgs.append(org.content.encode('ascii','ignore'))
    print orgs
    return orgs

def get_data(dom, orgs):
    
    org_list = {}
    
    #get org-wise coordinators
    coordinators = []
    for li, org in zip(dom.by_attr(style='list-style-type:none'), orgs):
        org_list[org] = {'coordinator' : (li.content.split("<span ")[0].split(":")[-1]).encode('ascii','ignore')}
    
    #get org-wise mentees and their all details
    mentees = {}
    i = 0
    for li in dom.by_tag('li'):
        content = li.content
        match = re.search('coordinator', content)
        if match:
            org = orgs[i]
            i += 1
        else:
            #check for those mentee who don't have `link`
            match = re.search('<a', content)
            if match:
                name = li.by_tag('a')[0].content.encode('ascii','ignore')
                link = li.by_tag('a')[0].attributes.get('href', '').encode('ascii','ignore')
                content = content.split('</a>')[-1]
            else:
                name = content[ : content.index('(')].encode('ascii','ignore')
                link = ''
            print(name)
           
            #for those mentee who have not provided their nick
            if content[1] == '(':
                nick = content[content.index('(')+1 : content.index(')')].encode('ascii','ignore')
            else:
                nick = ""
            content = content[content.index(',')+2 : ].split('<span')[0]
            #print(content)
            
            #because some projects have ` - ` pattern in their name
            #address, project, mentor = content.split(' - ')
            a = content.find(' - ')
            address = content[: a].encode('ascii','ignore')
            b = content.rfind(' - ')
            mentor = content[b+2 :].encode('ascii','ignore')
            project = content[a+2 : b].encode('ascii','ignore')
            
            mentee = {'nick': nick, 'name': name, 'link':link, 'address':address, 'project':project, 'mentor':mentor}
            org_list[org].setdefault('mentees', []).append(mentee)
            
    # step - 4 Write whole data in a csv file
    with open('outreachy_students', 'w') as csvfile:
        filewriter = csv.writer(csvfile, delimiter='\t',
                            quotechar='|', quoting=csv.QUOTE_MINIMAL)
        filewriter.writerow(['Name', 'Link',  'Nick', 'Org', 'Project', 'Address', 'Mentor', 'Coordinators'])
        for org in orgs:
            for mentee in org_list[org]['mentees']:
                filewriter.writerow([mentee['name'], mentee['link'], mentee['nick'],
                                     org, mentee['project'], mentee['address'], mentee['mentor'],
                                     org_list[org]['coordinator']])
        print('Done!!')
            
    #for 
    print(org_list)
    
dom = get_html("https://wiki.gnome.org/Outreachy/2015/MayAugust#Accepted_Participants")    
orgs = get_orgs(dom)
final = get_data(dom, orgs)
# Out:
# Congratulations to 30
# Congratulations to 30 participants accepted for Outreachy! <span class="anchor" id="line-62"></span><span class="anchor" id="line-63"></span><p class="line874">Applicants who are students applying to work on the coding projects were encouraged to apply for Google Summer of Code as well. The administrators of both programs then coordinated to accept the top applicants for one of the programs. Congratulations to 3 applicants who applied for both Outreachy and Google Summer of Code, and were accepted for Google Summer of Code with organizations participating in both programs! <span class="anchor" id="line-64"></span><span class="anchor" id="line-65"></span></p><p class="line862">Additionally, congratulations to 1 more applicant who was accepted for OpenDaylight Internship Program! <span class="anchor" id="line-66"></span><span class="anchor" id="line-67"></span></p><p class="line867">
# <h2 id="Ceph">Ceph</h2>
# <span class="anchor" id="line-68"></span><span class="anchor" id="line-69"></span><ul><li style="list-style-type:none"><p class="line862">coordinator: Patrick McGarry <span class="anchor" id="line-70"></span><span class="anchor" id="line-71"></span></p></li><li class="gap"><p class="line891"><a class="https" href="https://jeketam.wordpress.com/">Jessica Mack</a> (Jekt), Tampa, FL, USA - Community documentation - Patrick McGarry <span class="anchor" id="line-72"></span></p></li><li><p class="line891"><a class="https" href="https://opensourcednish.wordpress.com/">Nishtha Rai</a> (nishR), Bengaluru, Karnataka, India - CephFS security for multitenancy - Sage Weil <span class="anchor" id="line-73"></span><span class="anchor" id="line-74"></span></p></li></ul></p><p class="line867">
# <h2 id="Debian">Debian</h2>
# <span class="anchor" id="line-75"></span><span class="anchor" id="line-76"></span><ul><li style="list-style-type:none">coordinators: Tom Marble and Nicolas Dandrimont <span class="anchor" id="line-77"></span><span class="anchor" id="line-78"></span></li><li class="gap">Akshita Jha (GSoC) (akshita), Hyderabad, Andhra Pradesh, India - Blends Web Sentinel - Andreas Tille <span class="anchor" id="line-79"></span><span class="anchor" id="line-80"></span></li></ul></p><p class="line867">
# <h2 id="FFmpeg">FFmpeg</h2>
# <span class="anchor" id="line-81"></span><span class="anchor" id="line-82"></span><ul><li style="list-style-type:none">coordinators: Stefano Sabatini, Michael Niedermayer, and Reynaldo Verdejo <span class="anchor" id="line-83"></span><span class="anchor" id="line-84"></span></li><li class="gap"><p class="line891"><a class="http" href="http://lglinskih.blogspot.com/">Ludmila Glinskih</a> (lglinskih), St. Petersburg, Russia - API regression testing - Kieran Kunhya <span class="anchor" id="line-85"></span><span class="anchor" id="line-86"></span></p></li></ul></p><p class="line867">
# <h2 id="GNOME">GNOME</h2>
# <span class="anchor" id="line-87"></span><span class="anchor" id="line-88"></span><ul><li style="list-style-type:none">coordinator: Marina Zhurakhinskaya <span class="anchor" id="line-89"></span><span class="anchor" id="line-90"></span></li><li class="gap"><p class="line891"><a class="https" href="https://ginadobrescu.wordpress.com/">Gina Dobrescu</a> (ginux),  Grenoble, France - Usability testing - Jim Hall <span class="anchor" id="line-91"></span><span class="anchor" id="line-92"></span></p></li></ul></p><p class="line867">
# <h2 id="GStreamer">GStreamer</h2>
# <span class="anchor" id="line-93"></span><span class="anchor" id="line-94"></span><ul><li style="list-style-type:none">coordinator: Reynaldo Verdejo <span class="anchor" id="line-95"></span><span class="anchor" id="line-96"></span></li><li class="gap"><p class="line891"><a class="http" href="http://vchipi.blogspot.com.es/">Vanessa Chipirrás Navalón</a> (vanechipi), Seville, Spain - OpenCV gesture detection - Thiago Santos <span class="anchor" id="line-97"></span><span class="anchor" id="line-98"></span></p></li></ul></p><p class="line867">
# <h2 id="Linux_kernel">Linux kernel</h2>
# <span class="anchor" id="line-99"></span><span class="anchor" id="line-100"></span><ul><li style="list-style-type:none">coordinator: Julia Lawall <span class="anchor" id="line-101"></span><span class="anchor" id="line-102"></span></li><li class="gap"><p class="line891"><a class="http" href="http://helenfornazier.blogspot.com.br/">Helen Fornazier</a> (koike),  Campinas/Sao Paulo, Brazil - Media controller virtual driver - Laurent Pinchart <span class="anchor" id="line-103"></span></p></li><li><p class="line891"><a class="https" href="https://vatikaharlalka.wordpress.com">Vatika Harlalka</a> (vatika), Hyderabad, Andhra Pradesh, India - Full dynamic ticks - Preeti U Murthy and Frederic Weisbecker <span class="anchor" id="line-104"></span></p></li><li><p class="line891"><a class="http" href="http://mahfouzsaif.blogspot.com/">Aya Mahfouz</a> (asaifm), Cairo, Egypt - Modernize Linux wireless drivers - Kyle McMartin and Jes Sorensen <span class="anchor" id="line-105"></span></p></li><li><p class="line891"><a class="http" href="http://cristina2689.github.io/">Cristina Georgiana Opriceana</a> (cristina_opr), Bucharest, Romania - IIO dummy driver - Daniel Baluta and Octavian Purdila <span class="anchor" id="line-106"></span></p></li><li><p class="line891"><a class="http" href="http://vthakkar1994.wordpress.com/">Vaishali Thakkar</a> (vaishu), Gandhinagar, Gujarat, India - Coccinelle - Julia Lawall <span class="anchor" id="line-107"></span><span class="anchor" id="line-108"></span></p></li></ul></p><p class="line867">
# <h2 id="Measurement_Lab">Measurement Lab</h2>
# <span class="anchor" id="line-109"></span><span class="anchor" id="line-110"></span><ul><li style="list-style-type:none"><p class="line862">coordinators: Steph Alacron and Jordan McCarthy <span class="anchor" id="line-111"></span><span class="anchor" id="line-112"></span></p></li><li class="gap"><p class="line891"><a class="http" href="http://www.nthturn.com">Kinga Farkas</a> (katalinka), Portland, OR, USA - Assess performance impact of major regulatory changes - Jordan McCarthy, Steph Alarcon, and Georgia Bullen <span class="anchor" id="line-113"></span></p></li><li><p class="line891"><a class="http" href="http://elf11.github.io/">Oana-Georgiana Niculaescu</a> (elf11), Bucharest, Romania - Socieconomic geography of access &amp; performance - Jordan McCarthy, Steph Alarcon, and Georgia Bullen <span class="anchor" id="line-114"></span><span class="anchor" id="line-115"></span></p></li></ul></p><p class="line867">
# <h2 id="Mesos_and_Pants">Mesos and Pants</h2>
# <span class="anchor" id="line-116"></span><span class="anchor" id="line-117"></span><ul><li style="list-style-type:none">coordinator: Chris Aniszczyk <span class="anchor" id="line-118"></span><span class="anchor" id="line-119"></span></li><li class="gap"><p class="line891"><a class="http" href="http://shardsandfragments.blogspot.com">Aditi Dixit</a> (atidix), New Delhi, India - Updating FrameworkInfo in Mesos - Vinod Kone <span class="anchor" id="line-120"></span></p></li><li><p class="line891"><a class="http" href="http://rushprog.blogspot.com/">Raushaniya Maksudova</a>, Moscow, Russia - Pants plugin wizard -  Fedor Korotkov and Tejal Desai <span class="anchor" id="line-121"></span><span class="anchor" id="line-122"></span></p></li></ul></p><p class="line867">
# <h2 id="Mozilla">Mozilla</h2>
# <span class="anchor" id="line-123"></span><span class="anchor" id="line-124"></span><ul><li style="list-style-type:none">coordinator: Christie Koehler <span class="anchor" id="line-125"></span><span class="anchor" id="line-126"></span></li><li class="gap"><p class="line891"><a class="http" href="http://tchanoutreachy.wordpress.com">Thalia Chan</a> (Tchanders), London, UK - Socorro crash statistics front-end development - Adrian Gaudebert <span class="anchor" id="line-127"></span></p></li><li><p class="line891"><a class="http" href="http://explique.me">Alice Duarte Scarpa</a> (adusca), Rio de Janeiro, Brazil - Integrate the ability to arbitrarily retrigger jobs into functional tools &amp; production quality code - Armen Zambrano Gasparnian <span class="anchor" id="line-128"></span></p></li><li><p class="line891"><a class="http" href="http://gloriadwomoh.me/blog/">Gloria Dwomoh</a> (blossomica), Piraeus, Greece - Air Mozilla web design and development - Peter Bengtsson <span class="anchor" id="line-129"></span><span class="anchor" id="line-130"></span></p></li></ul></p><p class="line867">
# <h2 id="OpenDaylight">OpenDaylight</h2>
# <span class="anchor" id="line-131"></span><span class="anchor" id="line-132"></span><ul><li style="list-style-type:none">coordinators: Phil Robb and Todd Benzies <span class="anchor" id="line-133"></span><span class="anchor" id="line-134"></span></li><li class="gap"><p class="line862">Deanna Hambleton (OpenDaylight Internship Program) (zigzg), Cambridge, MA, USA - Spectrometer - Thomas Nadeau <span class="anchor" id="line-135"></span><span class="anchor" id="line-136"></span></p></li></ul></p><p class="line867">
# <h2 id="OpenStack">OpenStack</h2>
# <span class="anchor" id="line-137"></span><span class="anchor" id="line-138"></span><ul><li style="list-style-type:none">coordinators: Stefano Maffulli and Victoria Martínez de la Cruz <span class="anchor" id="line-139"></span><span class="anchor" id="line-140"></span></li><li class="gap"><p class="line891"><a class="http" href="http://blog.taron.io/">Emma Barber</a> (taron), Portland, OR, USA - Running hound as part of infra - Elizabeth Joseph <span class="anchor" id="line-141"></span></p></li><li><p class="line891"><a class="https" href="https://geetikabatra.wordpress.com/">Geetika Batra</a> (GB21), India - Implementation of tasks scrubber in Glance - Nikhil Komawar <span class="anchor" id="line-142"></span></p></li><li><p class="line891"><a class="https" href="https://dynarro.wordpress.com">Doraly Navarro</a> (dynarro), Como, Italy - zaqar-pythonclient support for Zaqar API v1.1 - Victoria Martínez de la Cruz <span class="anchor" id="line-143"></span><span class="anchor" id="line-144"></span></p></li></ul></p><p class="line867">
# <h2 id="OpenStreetMap">OpenStreetMap</h2>
# <span class="anchor" id="line-145"></span><span class="anchor" id="line-146"></span><ul><li style="list-style-type:none">coordinators: Kate Chapman and Mhairi O'Hara <span class="anchor" id="line-147"></span><span class="anchor" id="line-148"></span></li><li class="gap"><p class="line891"><a class="https" href="https://yachtsmandev.wordpress.com/">Anwar Abdul-Azim</a> (Anwaario), Vallejo, CA, USA - Improve LearnOSM content and organisation - Nick Allen and Benoît Fournier <span class="anchor" id="line-149"></span></p></li><li><p class="line891"><a class="https" href="https://www.openstreetmap.org/user/tassia/diary/">Tassia Camoes Araujo</a> (tassia), Montreal, Quebec, Canada - Develop a QGIS plugin for OpenAerialMap - Cristiano Giovando <span class="anchor" id="line-150"></span></p></li><li><p class="line891"><a class="https" href="https://goblinrefuge.com/mediagoblin/u/rekth/b/dashboard/">Rekth K</a> (rekth),  Amsterdam, The Netherlands - Usability testing for the HOT Tasking Manager user interface - Blake Girardot <span class="anchor" id="line-151"></span></p></li><li><p class="line891"><a class="http" href="http://www.openstreetmap.org/user/Arushi%20Vashist/diary">Arushi Vashist</a> (arvst), Hyderabad, Andhra Pradesh, India - Improve help documentation of HOT Export Tool features on homepage - Mhairi O'Hara <span class="anchor" id="line-152"></span><span class="anchor" id="line-153"></span></p></li></ul></p><p class="line867">
# <h2 id="oVirt">oVirt</h2>
# <span class="anchor" id="line-154"></span><span class="anchor" id="line-155"></span><ul><li style="list-style-type:none">coordinator: Brian Proffitt <span class="anchor" id="line-156"></span><span class="anchor" id="line-157"></span></li><li class="gap"><p class="line891"><a class="http" href="http://noisedoll.blogspot.com/">Nika Burimenko</a> (NoiseDoll), Vladivostok, Russia - moVirt - Tomas Jelinek <span class="anchor" id="line-158"></span></p></li><li><p class="line891"><a class="https" href="https://yixinzhang0225.wordpress.com/">Yixin Zhang</a>, Los Angeles, CA, USA - moVirt - Tomas Jelinek <span class="anchor" id="line-159"></span><span class="anchor" id="line-160"></span></p></li></ul></p><p class="line867">
# <h2 id="Perl">Perl</h2>
# <span class="anchor" id="line-161"></span><span class="anchor" id="line-162"></span><ul><li style="list-style-type:none">coordinator: Karen Pauley <span class="anchor" id="line-163"></span><span class="anchor" id="line-164"></span></li><li class="gap">Sakshee Vijay (ivory), Hyderabad, Andhra Pradesh, India - Decoupling the Dancer2 application discoverability and contributor's guide - Sawyer X <span class="anchor" id="line-165"></span><span class="anchor" id="line-166"></span></li></ul></p><p class="line867">
# <h2 id="VideoLAN">VideoLAN</h2>
# <span class="anchor" id="line-167"></span><span class="anchor" id="line-168"></span><ul><li style="list-style-type:none">coordinators: Felix Paul Kühne and Carola Nitz <span class="anchor" id="line-169"></span><span class="anchor" id="line-170"></span></li><li class="gap">Sushma Reddy Devireddy (sushmareddy), Hyderabad, Andhra Pradesh, India - Timed text TTML support - Jean-Baptiste Kempf <span class="anchor" id="line-171"></span><span class="anchor" id="line-172"></span></li></ul></p><p class="line867">
# <h2 id="Wikimedia">Wikimedia</h2>
# <span class="anchor" id="line-173"></span><span class="anchor" id="line-174"></span><ul><li style="list-style-type:none">coordinators: Quim Gil and Niharika Kohli <span class="anchor" id="line-175"></span><span class="anchor" id="line-176"></span></li><li class="gap"><p class="line891"><a class="https" href="https://phoenixpedia.wordpress.com">Dibya Singh</a> (Phoenix303), India - Reinvent translation search - Niklas Laxström and Federico Leva <span class="anchor" id="line-177"></span></p></li><li>Tina Johnson (GSoC) (tinajohnson), Kerala, India - Newsletter Mediawiki extension - Quim Gil and Tony Thomas <span class="anchor" id="line-178"></span></li><li><p class="line862">Ankita Kumari (GSoC) (ankita-ks), Hyderabad, Andhra Pradesh, India -  Unified language proofing tools integration framework in VisualEditor - Amir Aharoni <span class="anchor" id="line-179"></span><span class="anchor" id="line-180"></span></p></li></ul></p><p class="line867">
# <h2 id="Xen_Project">Xen Project</h2>
# <span class="anchor" id="line-181"></span><span class="anchor" id="line-182"></span><ul><li style="list-style-type:none">coordinators: Lars Kurth and Russell Pavlicek <span class="anchor" id="line-183"></span><span class="anchor" id="line-184"></span></li><li class="gap"><p class="line891"><a class="http" href="http://lindasoutreachy.blogspot.com">Linda Jacobson</a> (lindaj), Boulder, CO, USA - Implementing a classic Xen front/back pv driver pair to provide a transport for 9P FS - Julien Grall and Wei Liu <span class="anchor" id="line-185"></span><span class="anchor" id="line-186"></span></p></li></ul></p><p class="line867">
# </p>
# ['Ceph', 'Debian', 'FFmpeg', 'GNOME', 'GStreamer', 'Linux kernel', 'Measurement Lab', 'Mesos and Pants', 'Mozilla', 'OpenDaylight', 'OpenStack', 'OpenStreetMap', 'oVirt', 'Perl', 'VideoLAN', 'Wikimedia', 'Xen Project']
# Jessica Mack
# Nishtha Rai
# Akshita Jha
# Ludmila Glinskih
# Gina Dobrescu
# Vanessa Chipirrs Navaln
# Helen Fornazier
# Vatika Harlalka
# Aya Mahfouz
# Cristina Georgiana Opriceana
# Vaishali Thakkar
# Kinga Farkas
# Oana-Georgiana Niculaescu
# Aditi Dixit
# Raushaniya Maksudova
# Thalia Chan
# Alice Duarte Scarpa
# Gloria Dwomoh
# <p class="line862">Deanna Hambleton
# Emma Barber
# Geetika Batra
# Doraly Navarro
# Anwar Abdul-Azim
# Tassia Camoes Araujo
# Rekth K
# Arushi Vashist
# Nika Burimenko
# Yixin Zhang
# Sakshee Vijay
# Sushma Reddy Devireddy
# Dibya Singh
# Tina Johnson
# <p class="line862">Ankita Kumari
# Linda Jacobson
# Done!!
# {'OpenStreetMap': {'coordinator': " Kate Chapman and Mhairi O'Hara ", 'mentees': [{'name': 'Anwar Abdul-Azim', 'project': ' Improve LearnOSM content and organisation', 'nick': 'Anwaario', 'link': 'https://yachtsmandev.wordpress.com/', 'mentor': ' Nick Allen and Benot Fournier ', 'address': 'Vallejo, CA, USA'}, {'name': 'Tassia Camoes Araujo', 'project': ' Develop a QGIS plugin for OpenAerialMap', 'nick': 'tassia', 'link': 'https://www.openstreetmap.org/user/tassia/diary/', 'mentor': ' Cristiano Giovando ', 'address': 'Montreal, Quebec, Canada'}, {'name': 'Rekth K', 'project': ' Usability testing for the HOT Tasking Manager user interface', 'nick': 'rekth', 'link': 'https://goblinrefuge.com/mediagoblin/u/rekth/b/dashboard/', 'mentor': ' Blake Girardot ', 'address': ' Amsterdam, The Netherlands'}, {'name': 'Arushi Vashist', 'project': ' Improve help documentation of HOT Export Tool features on homepage', 'nick': 'arvst', 'link': 'http://www.openstreetmap.org/user/Arushi%20Vashist/diary', 'mentor': " Mhairi O'Hara ", 'address': 'Hyderabad, Andhra Pradesh, India'}]}, 'Mesos and Pants': {'coordinator': ' Chris Aniszczyk ', 'mentees': [{'name': 'Aditi Dixit', 'project': ' Updating FrameworkInfo in Mesos', 'nick': 'atidix', 'link': 'http://shardsandfragments.blogspot.com', 'mentor': ' Vinod Kone ', 'address': 'New Delhi, India'}, {'name': 'Raushaniya Maksudova', 'project': ' Pants plugin wizard', 'nick': '', 'link': 'http://rushprog.blogspot.com/', 'mentor': '  Fedor Korotkov and Tejal Desai ', 'address': 'Moscow, Russia'}]}, 'oVirt': {'coordinator': ' Brian Proffitt ', 'mentees': [{'name': 'Nika Burimenko', 'project': ' moVirt', 'nick': 'NoiseDoll', 'link': 'http://noisedoll.blogspot.com/', 'mentor': ' Tomas Jelinek ', 'address': 'Vladivostok, Russia'}, {'name': 'Yixin Zhang', 'project': ' moVirt', 'nick': '', 'link': 'https://yixinzhang0225.wordpress.com/', 'mentor': ' Tomas Jelinek ', 'address': 'Los Angeles, CA, USA'}]}, 'Mozilla': {'coordinator': ' Christie Koehler ', 'mentees': [{'name': 'Thalia Chan', 'project': ' Socorro crash statistics front-end development', 'nick': 'Tchanders', 'link': 'http://tchanoutreachy.wordpress.com', 'mentor': ' Adrian Gaudebert ', 'address': 'London, UK'}, {'name': 'Alice Duarte Scarpa', 'project': ' Integrate the ability to arbitrarily retrigger jobs into functional tools &amp; production quality code', 'nick': 'adusca', 'link': 'http://explique.me', 'mentor': ' Armen Zambrano Gasparnian ', 'address': 'Rio de Janeiro, Brazil'}, {'name': 'Gloria Dwomoh', 'project': ' Air Mozilla web design and development', 'nick': 'blossomica', 'link': 'http://gloriadwomoh.me/blog/', 'mentor': ' Peter Bengtsson ', 'address': 'Piraeus, Greece'}]}, 'GNOME': {'coordinator': ' Marina Zhurakhinskaya ', 'mentees': [{'name': 'Gina Dobrescu', 'project': ' Usability testing', 'nick': 'ginux', 'link': 'https://ginadobrescu.wordpress.com/', 'mentor': ' Jim Hall ', 'address': ' Grenoble, France'}]}, 'Xen Project': {'coordinator': ' Lars Kurth and Russell Pavlicek ', 'mentees': [{'name': 'Linda Jacobson', 'project': ' Implementing a classic Xen front/back pv driver pair to provide a transport for 9P FS', 'nick': 'lindaj', 'link': 'http://lindasoutreachy.blogspot.com', 'mentor': ' Julien Grall and Wei Liu ', 'address': 'Boulder, CO, USA'}]}, 'Wikimedia': {'coordinator': ' Quim Gil and Niharika Kohli ', 'mentees': [{'name': 'Dibya Singh', 'project': ' Reinvent translation search', 'nick': 'Phoenix303', 'link': 'https://phoenixpedia.wordpress.com', 'mentor': ' Niklas Laxstrm and Federico Leva ', 'address': 'India'}, {'name': 'Tina Johnson ', 'project': ' Newsletter Mediawiki extension', 'nick': '', 'link': '', 'mentor': ' Quim Gil and Tony Thomas ', 'address': 'Kerala, India'}, {'name': '<p class="line862">Ankita Kumari ', 'project': '  Unified language proofing tools integration framework in VisualEditor', 'nick': '', 'link': '', 'mentor': ' Amir Aharoni ', 'address': 'Hyderabad, Andhra Pradesh, India'}]}, 'GStreamer': {'coordi ...

# %% [markdown]
# ## Scraping for Round 4 and below

# %%
# pattern and beautifulsoup are for navigating through DOM
from pattern import web

import re

def get_html(url):
    """ Fetch the html code from given url
        Returns pattern.web.Element
    """
    html = web.URL(url, method='GET')
    #print(type(html.download())) # str
    html_doc = html.download()
    
    #Keeping html related to only accepted participants 
    mid = html_doc.split('id="Accepted_Participants"')
    required_html = mid[-1].split('id="For_Participants"')[0]
    
    dom = web.Element(required_html)
    #print(dom)
    print("done :)")
    return dom

def get_data(dom):

    mentees = {}
    i = 0
    for li in dom.by_tag('li'):
        content = li.content
        #check for those mentee who don't have `link`
        match = re.search('<a', content)
        if match:
            name = li.by_tag('a')[0].content.encode('ascii','ignore')
            link = li.by_tag('a')[0].attributes.get('href', '').encode('ascii','ignore')
            content = content.split('</a>')[-1]
        else:
            name = content[ : content.index('(')].encode('ascii','ignore')
            link = ''
            print(name)
           
        #for those mentee who have not provided their nick
        if content[1] == '(':
            nick = content[content.index('(')+1 : content.index(')')].encode('ascii','ignore')
        else:
            nick = ""
        content = content[content.index(',')+2 : ].split('<span')[0]
        #print(content)
            
        #because some projects have ` - ` pattern in their name
        #address, project, mentor = content.split(' - ')
        a = content.find(' - ')
        address = content[: a].encode('ascii','ignore')
        b = content.rfind(' - ')
        mentor = content[b+2 :].encode('ascii','ignore')
        project = content[a+2 : b].encode('ascii','ignore')
            
        mentee = {'nick': nick, 'name': name, 'link':link, 'address':address, 'project':project, 'mentor':mentor}
        mentees[name+nick] = mentee
            

    print('Done!!')
    print(mentees)
    
#dom = get_html("https://wiki.gnome.org/GnomeWomen/OutreachProgram2012#twisted-internship") # round-4
#dom = get_html("https://wiki.gnome.org/GnomeWomen/OutreachProgram2011") #round-3
dom = get_html("https://wiki.gnome.org/GnomeWomen/OutreachProgram2011/MayAugust#Accepted_Participants") #round-2
#dom = get_html("https://wiki.gnome.org/GnomeWomen/OutreachProgram2010#Accepted_Participants") #round-1
final = get_data(dom)
# Out:
# done :)
# Done!!
# {'Priscilla Mahlangupriny': {'name': 'Priscilla Mahlangu', 'project': ' Localization', 'nick': 'priny', 'link': 'http://gnomeoutreach.blogspot.com', 'mentor': ' Friedel Wolff ', 'address': 'Pretoria, South Africa'}, 'Tiffany Antopolskimimico': {'name': 'Tiffany Antopolski', 'project': ' Empathy', 'nick': 'mimico', 'link': 'http://mimico-tiffany.tumblr.com', 'mentor': ' Danielle Madeley ', 'address': 'Toronto, Canada'}, 'Aline Duarte Bessaalibezz': {'name': 'Aline Duarte Bessa', 'project': ' Documentation, Accessibility', 'nick': 'alibezz', 'link': 'http://alinebessa.wordpress.com', 'mentor': ' David Bolter and Joanmarie Diggs ', 'address': 'Salvador, Brazil'}, 'Liansu Yuyuliansu': {'name': 'Liansu Yu', 'project': ' Art', 'nick': 'yuliansu', 'link': 'http://yuliansu.wordpress.com', 'mentor': ' Andreas Nilsson ', 'address': 'Beijing, China'}, 'Anita Reiterenitalynx': {'name': 'Anita Reitere', 'project': ' Documentation', 'nick': 'nitalynx', 'link': 'http://nitalynx.wordpress.com', 'mentor': ' Phil Bull ', 'address': 'Riga, Latvia'}, 'Nohemi Fernandezfernandex': {'name': 'Nohemi Fernandez', 'project': ' GNOME Shell', 'nick': 'fernandex', 'link': 'http://justabovethetagclouds.blogspot.com', 'mentor': ' Dan Winship ', 'address': 'Chicago, USA'}, 'Tamara Atanasoskatamara': {'name': 'Tamara Atanasoska', 'project': ' Anjuta', 'nick': 'tamara', 'link': 'http://tamara.softver.org.mk', 'mentor': ' Johannes Schmid ', 'address': 'Skopje, Republic of Macedonia'}, 'Madhumitha Viswanathanmadhuvishy': {'name': 'Madhumitha Viswanathan', 'project': ' GTG', 'nick': 'madhuvishy', 'link': 'http://madhuslogs.tumblr.com', 'mentor': ' Luca Invernizzi ', 'address': 'Chennai, India'}, 'Neha Doijodesanjien': {'name': 'Neha Doijode', 'project': ' GNOME Shell', 'nick': 'sanjien', 'link': 'https://sanjien.wordpress.com', 'mentor': ' Marina Zhurakhinskaya ', 'address': 'Karnataka, India'}, 'Meg Fordm_22': {'name': 'Meg Ford', 'project': ' Art, Accessibility', 'nick': 'm_22', 'link': 'http://fordmeg.blogspot.com', 'mentor': ' David Bolter and Andreas Nilsson ', 'address': 'Chicago, USA'}, 'Julita Incayulys': {'name': 'Julita Inca', 'project': ' Documentation', 'nick': 'yulys', 'link': 'http://lleksah.wordpress.com', 'mentor': ' Phil Bull ', 'address': 'Lima, Peru'}, 'Ekaterina Gerasimovakittykat': {'name': 'Ekaterina Gerasimova', 'project': ' Documentation', 'nick': 'kittykat', 'link': 'http://blogs.gnome.org/kittykat/', 'mentor': ' Shaun McCance ', 'address': 'Berlin, Germany'}, 'Srishti SethiSrishAkaTux': {'name': 'Srishti Sethi', 'project': ' GCompris', 'nick': 'SrishAkaTux', 'link': 'http://srishtisethi.blogspot.com', 'mentor': ' Bruno Coudoin ', 'address': 'Rajasthan, India'}, 'Raluca Elena Podiucmimi': {'name': 'Raluca Elena Podiuc', 'project': ' Cheese', 'nick': 'mimi', 'link': 'http://building-a-black-hole.blogspot.com', 'mentor': ' Luciana Fujii Pontello ', 'address': 'Bucharest, Romania'}, 'Kelly Sinnottpolymathica': {'name': 'Kelly Sinnott', 'project': ' Documentation', 'nick': 'polymathica', 'link': 'https://web.archive.org/web/20130404214912/http://polymathica.posterous.com/', 'mentor': ' Shaun McCance ', 'address': 'Las Vegas, USA'}}
